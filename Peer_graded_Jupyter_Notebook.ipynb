# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Ángel Norman Zapata Sumano**
#
# Business Intelligence Engineer || Data Scientist

# %% [markdown]
# *I am interested in data science because I enjoy finding meaningful insights and innovative solutions. I am also deeply interested in how technology is changing the way the industries manage and generate information.*

# %% [markdown]
# ### The following function will take two integers as an input, add them and display the result in binary value.

# %%
def binary_sum(a,b):
    res = a+b
    return format(res, 'b')

binary_sum(9,3)
# Out:
# '1100'

# %% [markdown]
# <ol>
#     <li>This</li>
#     <li>Is</li>
#     <li>A</li>
#     <li>Numbered</li>
#     <li>List</li>
# </ol>
#
# ***
#
# - This is a bulleted list:
#     - Or
#     - Is
#     - It?
#
# ***
#
# <div class="alert alert-block alert-info">
#     <b>Tip:</b> Always say <i>please</i> and <i>thank you</i>.
# </div>
#
# ![image info](https://external-content.duckduckgo.com/iu/?u=http%3A%2F%2F4.bp.blogspot.com%2F-0qaKFW_ibnI%2FVGcCQJ7OejI%2FAAAAAAAAAP8%2FBGGnvMC_KFc%2Fs1600%2Fhungry%252Bfor.JPG&f=1&nofb=1&ipt=7aa3b45a80e9f1098b09d8e06e8aaf074f94bf85d546a9a02cdfb205100c09e1&ipo=images)
